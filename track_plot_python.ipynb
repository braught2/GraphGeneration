# %%
#First let's import all the libraries and the packages needed to plot the track
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline

# %%
figure, axes = plt.subplots()

axes.set(xlim=(1,10),ylim=(1,11))
first_circle = plt.Circle((5,5),2.7,fill = False)

axes.add_artist(first_circle)
plt.title('Race Track')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()
